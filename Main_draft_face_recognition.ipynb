# %% [markdown]
# <a href="https://colab.research.google.com/github/ishitaahuja15/Basic-Scientific-Calculator-Cpp/blob/main/Main_draft_face_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clone Repository

# %%
# !git clone https://github.com/ishitaahuja15/face_recognition.git
# %cd face_recognition
# Out:
# Cloning into 'face_recognition'...
# remote: Enumerating objects: 359, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 359 (delta 5), reused 53 (delta 5), pack-reused 306
# Receiving objects: 100% (359/359), 45.92 MiB | 29.48 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/face_recognition/face_recognition/face_recognition/face_recognition

# %% [markdown]
# # Install Face Recognition from pip

# %%
# !pip install face_recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Passing images to train

# %%
import face_recognition
import numpy as np
from PIL import Image, ImageDraw
from IPython.display import display


face_1 = face_recognition.load_image_file("Aaron Mooy.png")
face_1_encoding = face_recognition.face_encodings(face_1)[0]

face_2 = face_recognition.load_image_file("Abdul Samad.jpg")
face_2_encoding = face_recognition.face_encodings(face_2)[0]

face_3 = face_recognition.load_image_file("Abhinav Manohar.jpg")
face_3_encoding = face_recognition.face_encodings(face_3)[0]

face_4 = face_recognition.load_image_file("Abhishek Sharma.jpg")
face_4_encoding = face_recognition.face_encodings(face_4)[0]

face_5 = face_recognition.load_image_file("Adam Taggart.jpg")
face_5_encoding = face_recognition.face_encodings(face_5)[0]

face_6 = face_recognition.load_image_file("Adam Zampa.webp")
face_6_encoding = face_recognition.face_encodings(face_6)[0]

face_7 = face_recognition.load_image_file("Adil Rashid.webp")
face_7_encoding = face_recognition.face_encodings(face_7)[0]

face_8 = face_recognition.load_image_file("Adrien Rabiot.webp")
face_8_encoding = face_recognition.face_encodings(face_8)[0]

face_9 = face_recognition.load_image_file("Aiden Markram.webp")
face_9_encoding = face_recognition.face_encodings(face_9)[0]

face_10 = face_recognition.load_image_file("Ajay Mandal.jpg")
face_10_encoding = face_recognition.face_encodings(face_10)[0]

face_11 = face_recognition.load_image_file("Ajdin Hrustic.jpg")
face_11_encoding = face_recognition.face_encodings(face_11)[0]

face_12 = face_recognition.load_image_file("Ajinkya Rahane.webp")
face_12_encoding = face_recognition.face_encodings(face_12)[0]

face_13 = face_recognition.load_image_file("Akash Deep.jpg")
face_13_encoding = face_recognition.face_encodings(face_13)[0]

face_14 = face_recognition.load_image_file("Akash Madhwal.jpg")
face_14_encoding = face_recognition.face_encodings(face_14)[0]

face_15 = face_recognition.load_image_file("Akash Vashisht.webp")
face_15_encoding = face_recognition.face_encodings(face_15)[0]

face_16 = face_recognition.load_image_file("Akeal Hosein.png")
face_16_encoding = face_recognition.face_encodings(face_16)[0]

face_17 = face_recognition.load_image_file("Alex Sandro.jpg")
face_17_encoding = face_recognition.face_encodings(face_17)[0]

face_18 = face_recognition.load_image_file("Alisson Becker.jpg")
face_18_encoding = face_recognition.face_encodings(face_18)[0]

face_19 = face_recognition.load_image_file("Alzarri Joseph.jpeg")
face_19_encoding = face_recognition.face_encodings(face_19)[0]

face_20 = face_recognition.load_image_file("Aman Khan.jpg")
face_20_encoding = face_recognition.face_encodings(face_20)[0]

face_21 = face_recognition.load_image_file("Ambati Rayudu.jpg")
face_21_encoding = face_recognition.face_encodings(face_21)[0]

face_22 = face_recognition.load_image_file("Amit Mishra.jpg")
face_22_encoding = face_recognition.face_encodings(face_22)[0]

face_23 = face_recognition.load_image_file("Andrew Redmayne.jpg")
face_23_encoding = face_recognition.face_encodings(face_23)[0]

face_24 = face_recognition.load_image_file("Angel Di Maria.jpg")
face_24_encoding = face_recognition.face_encodings(face_24)[0]

face_25 = face_recognition.load_image_file("Anmolpreet Singh.jpg")
face_25_encoding = face_recognition.face_encodings(face_25)[0]

face_26 = face_recognition.load_image_file("Anrich Nortje.jpeg")
face_26_encoding = face_recognition.face_encodings(face_26)[0]

face_27 = face_recognition.load_image_file("Antoine Griezmann.webp")
face_27_encoding = face_recognition.face_encodings(face_27)[0]

face_28 = face_recognition.load_image_file("Anuj Rawat.jpeg")
face_28_encoding = face_recognition.face_encodings(face_28)[0]

face_29 = face_recognition.load_image_file("Anukul Roy.webp")
face_29_encoding = face_recognition.face_encodings(face_29)[0]

face_30 = face_recognition.load_image_file("Apostolos Giannou.jpg")
face_30_encoding = face_recognition.face_encodings(face_30)[0]

face_31 = face_recognition.load_image_file("Arshad khan.jpg")
face_31_encoding = face_recognition.face_encodings(face_31)[0]

face_32 = face_recognition.load_image_file("Arshdeep Singh.jpg")
face_32_encoding = face_recognition.face_encodings(face_32)[0]

face_33 = face_recognition.load_image_file("Atharva Taide.jpg")
face_33_encoding = face_recognition.face_encodings(face_33)[0]

face_34 = face_recognition.load_image_file("Avesh Khan.webp")
face_34_encoding = face_recognition.face_encodings(face_34)[0]

face_35 = face_recognition.load_image_file("Avinash Singh.png")
face_35_encoding = face_recognition.face_encodings(face_35)[0]

face_36 = face_recognition.load_image_file("Virat Kohli.png")
face_36_encoding = face_recognition.face_encodings(face_36)[0]

face_37 = face_recognition.load_image_file("Axar Patel.jpg")
face_37_encoding = face_recognition.face_encodings(face_37)[0]

face_38 = face_recognition.load_image_file("Aymeric Laporte.jpg")
face_38_encoding = face_recognition.face_encodings(face_38)[0]

face_39 = face_recognition.load_image_file("Ayush-Badoni.jpg")
face_39_encoding = face_recognition.face_encodings(face_39)[0]

face_40 = face_recognition.load_image_file("Aziz Behich.jpg")
face_40_encoding = face_recognition.face_encodings(face_40)[0]

face_41 = face_recognition.load_image_file("Bailey Wright.jpg")
face_41_encoding = face_recognition.face_encodings(face_41)[0]

face_42 = face_recognition.load_image_file("Baltej-Dhanda.jpg")
face_42_encoding = face_recognition.face_encodings(face_42)[0]

face_43 = face_recognition.load_image_file("Ben Stokes.jpeg")
face_43_encoding = face_recognition.face_encodings(face_43)[0]

face_44 = face_recognition.load_image_file("Benjamin Pavard.jpeg")
face_44_encoding = face_recognition.face_encodings(face_44)[0]

face_45 = face_recognition.load_image_file("Bhagath Varma.jpg")
face_45_encoding = face_recognition.face_encodings(face_45)[0]

face_46 = face_recognition.load_image_file("Bhanuka-Rajapaksa.jpg")
face_46_encoding = face_recognition.face_encodings(face_46)[0]

face_47 = face_recognition.load_image_file("Rishabh Pant.jpeg")
face_47_encoding = face_recognition.face_encodings(face_47)[0]





known_face_encodings = [
    face_1_encoding,
    face_2_encoding,
    face_3_encoding,
    face_4_encoding,
    face_5_encoding,
    face_6_encoding,
    face_7_encoding,
    face_8_encoding,
    face_9_encoding,
    face_10_encoding,
    face_11_encoding,
    face_12_encoding,
    face_13_encoding,
    face_14_encoding,
    face_15_encoding,
    face_16_encoding,
    face_17_encoding,
    face_18_encoding,
    face_19_encoding,
    face_20_encoding,
    face_21_encoding,
    face_22_encoding,
    face_23_encoding,
    face_24_encoding,
    face_25_encoding,
    face_26_encoding,
    face_27_encoding,
    face_28_encoding,
    face_29_encoding,
    face_30_encoding,
    face_31_encoding,
    face_32_encoding,
    face_33_encoding,
    face_34_encoding,
    face_35_encoding,
    face_36_encoding,
    face_37_encoding,
    face_38_encoding,
    face_39_encoding,
    face_40_encoding,
    face_41_encoding,
    face_42_encoding,
    face_43_encoding,
    face_44_encoding,
    face_45_encoding,
    face_46_encoding,
    face_47_encoding

  
]

known_face_names = [
    "Aaron Mooy,Footballer",
    "Abdul Samad,Cricketer",
    "Abhinav Manohar,Cricketer",
    "Abhishek Sharma,Cricketer",
    "Adam Taggart,Footballer",
    "Adam Zampa,Cricketer",
    "Adil Rashid,Cricketer",
    "Adrien Rabiot,Footballer",
    "Aiden Markram,Cricketer",
    "Ajay Mandal,Cricketer",
    "Ajdin Hrustic,Footballer",
    "Ajinkya Rahane,Cricketer",
    "Akash Deep,Cricketer",
    "Akash Madhwal,Cricketer",
    "Akash Vashisht,Cricketer",
    "Akeal Hosein,Cricketer",
    "Alex Sandro,Footballer",
    "Alisson Becker,Footballer",
    "Alzarri Joseph,Cricketer",
    "Aman Khan,Cricketer",
    "Ambati Rayudu,Cricketer",
    "Amit Mishra,Cricketer",
    "Andrew Redmayne,Footballer",
    "Angel Di Maria,Footballer",
    "Anmolpreet Singh,Cricketer",
    "Anrich Nortje,Cricketer",
    "Antoine Griezmann,Footballer",
    "Antonio Rudiger,Footballer",
    "Anuj Rawat,Cricketer",
    "Anukul Roy,Cricketer",
    "Apostolos Giannou,Footballer",
    "Arshad khan,Cricketer",
    "Arshdeep Singh,Cricketer",
    "Atharva Taide,Cricketer",
    "Avesh Khan,Cricketer",
    "Avinash Singh,Cricketer",
    "Virat Kohli,Cricketer",
    "Aymeric Laporte,Footballer",
    "Ayush-Badoni,Cricketer",
    "Aziz Behich,Footballer",
    "Bailey Wright,Footballer",
    "Baltej Dhanda,Cricketer",
    "Ben Stokes,Cricketer",
    "Benjamin Pavard,Footballer",
    "Bhagath Varma,Cricketer",
    "Bhanuka-Rajapaksha,Cricketer",
    "Rishabh Pant,Cricketer"
    

  
]
print(known_face_encodings, "\n")
print("Done learning and creating profiles")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-c98be01d4c0d> in <module>
# ----> 1 import face_recognition
#       2 import numpy as np
#       3 from PIL import Image, ImageDraw
#       4 from IPython.display import display
#       5
#
# /usr/local/lib/python3.8/dist-packages/face_recognition/__init__.py in <module>
#       5 __version__ = '1.2.3'
#       6
# ----> 7 from .api import load_image_file, face_locations, batch_face_locations, face_landmarks, face_encodings, compare_faces, face_distance
#
# /usr/local/lib/python3.8/dist-packages/face_recognition/api.py in <module>
#      24
#      25 cnn_face_detection_model = face_recognition_models.cnn_face_detector_model_location()
# ---> 26 cnn_face_detector = dlib.cnn_face_detection_model_v1(cnn_face_detection_model)
#      27
# ...

# %% [markdown]
# # Testing Face Recognition using Images

# %%
unknown_image = face_recognition.load_image_file("319946.webp")

face_locations = face_recognition.face_locations(unknown_image)
face_encodings = face_recognition.face_encodings(unknown_image, face_locations)

pil_image = Image.fromarray(unknown_image)
draw = ImageDraw.Draw(pil_image)

for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
    # See if the face is a match for the known face(s)
    matches = face_recognition.compare_faces(known_face_encodings, face_encoding)

    name = "Unknown"

    face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
    best_match_index = np.argmin(face_distances)
    if matches[best_match_index]:
        name = known_face_names[best_match_index]

    # Draw a box around the face using the Pillow module
    draw.rectangle(((left, top), (right, bottom)), outline=(0, 255, 255))
    print(name)

    # Draw a label with a name below the face
    text_width, text_height = draw.textsize(name)
    # draw.rectangle(((left, bottom - text_height - 10), (right, bottom)), fill=(0, 0, 255), outline=(0, 0, 255))
    draw.text((left + 6, bottom - text_height + 30), name, fill=(255, 255, 255, 255))


# Remove the drawing library from memory as per the Pillow docs
del draw

# Display the resulting image
display(pil_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-718a127ad74c> in <module>
# ----> 1 unknown_image = face_recognition.load_image_file("319946.webp")
#       2
#       3 face_locations = face_recognition.face_locations(unknown_image)
#       4 face_encodings = face_recognition.face_encodings(unknown_image, face_locations)
#       5
#
# NameError: name 'face_recognition' is not defined

# %% [markdown]
# # Face Recognition in Videos

# %%
# Loading video for face detection
# %pylab inline
import cv2
import face_recognition
import cv2
import matplotlib.patches as patches
from IPython.display import clear_output
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt

video_capture = cv2.VideoCapture("WIN_20230217_12_52_56_Pro.mp4")
ret, frame = video_capture.read()
frame_height, frame_width, _ = frame.shape
out = cv2.VideoWriter('output.avi',cv2.VideoWriter_fourcc('M','J','P','G'), 10, (frame_width,frame_height))
frame_count = 0

while video_capture.isOpened():    
    # Grab a single frame of video
    ret, frame = video_capture.read()

    # Bail out when the video file ends
    if not ret:
        video_capture.release()
        break
        
    # We will search face in every 5 frames to speed up process.
    frame_count += 1
    if frame_count % 5 == 0:    
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Display video frame
        title("Input Stream")
        # plt.imshow(frame)        

        # Find all the faces and face encodings in the current frame of video
        rgb_frame = frame[:, :, ::-1]
        face_locations = face_recognition.face_locations(rgb_frame)
        face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

        for (face_location,face_encoding) in zip(face_locations,face_encodings):
          matches = face_recognition.compare_faces(known_face_encodings, face_encoding)

          name = "Unknown"

          face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
          best_match_index = np.argmin(face_distances)
          if matches[best_match_index]:
            name = known_face_names[best_match_index]
          # print(name)
          color = (0,0,)
          start_point = (face_location[3],face_location[0])
          end_point = (face_location[1],face_location[2])
          frame = cv2.rectangle(frame, start_point, end_point, color, 2) 
          frame = cv2.putText(frame,name,(face_location[3]-0, face_location[0]-20),cv2.FONT_HERSHEY_SIMPLEX, 2, color, 2, cv2.LINE_AA) 
          frame_copy = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
          out.write(frame_copy)
          plt.imshow(frame)

        

        # Show frame...
        plt.show() 
        # ... and hold it until a new frame appears
        clear_output(wait=True)
out.release()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-6f87f69f77e7> in <module>
#       2 get_ipython().run_line_magic('pylab', 'inline')
#       3 import cv2
# ----> 4 import face_recognition
#       5 import cv2
#       6 import matplotlib.patches as patches
#
# /usr/local/lib/python3.8/dist-packages/face_recognition/__init__.py in <module>
#       5 __version__ = '1.2.3'
#       6
# ----> 7 from .api import load_image_file, face_locations, batch_face_locations, face_landmarks, face_encodings, compare_faces, face_distance
#
# /usr/local/lib/python3.8/dist-packages/face_recognition/api.py in <module>
#      24
#      25 cnn_face_detection_model = face_recognition_models.cnn_face_detector_model_location()
# ---> 26 cnn_face_detector = dlib.cnn_face_detection_model_v1(cnn_face_detection_model)
# ...

# %% [markdown]
# ##Live Capture Face Detection

# %%
# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time

# %% [markdown]
# ## Helper Functions
# Below are a few helper function to make converting between different image data types and formats.

# %%
# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %% [markdown]
# ##Haar Cascade Classifier
# we will run a simple object detection algorithm called Haar Cascade on our images and video fetched from our webcam. OpenCV has a pre-trained Haar Cascade face detection model.

# %%
# initialize the Haar Cascade face detection model
face_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))

# %% [markdown]
# ##Webcam Images: Live Capture

# %%
def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)

  # get photo data
  data = eval_js('takePhoto({})'.format(quality))
  # get OpenCV format image
  img = js_to_image(data) 
  # grayscale img
  gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
  print(gray.shape)
  # get face bounding box coordinates using Haar Cascade
  faces = face_cascade.detectMultiScale(gray)
  # draw face bounding box on image
  for (x,y,w,h) in faces:
      img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
  # save image
  
  # Add a name below the square
  name = "Ishita, Student"  # replace with the name of the object
  cv2.putText(img, name, (x, y + h + 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

  cv2.imwrite(filename, img)

  return filename

# %%
try:
  filename = take_photo('photo.jpg')
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# (480, 640)
# Saved to photo.jpg

# %% [markdown]
# ##Webcam in videos
# Running code on webcam video is a little more complex than images. We need to start a video stream using our webcam as input. Then we run each frame through our progam (face detection) and create an overlay image that contains bounding box of detection(s). We then overlay the bounding box image back onto the next frame of our video stream

# %%
# JavaScript to properly create our live video stream using our webcam as input
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# %%
# start streaming video from webcam
video_stream()
# label for video
label_html = 'Capturing...'
# initialze bounding box to empty
bbox = ''
count = 0 
while True:
    js_reply = video_frame(label_html, bbox)
    if not js_reply:
        break

    # convert JS response to OpenCV Image
    img = js_to_image(js_reply["img"])

    # create transparent overlay for bounding box
    bbox_array = np.zeros([480,640,4], dtype=np.uint8)

    # grayscale image for face detection
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    # get face region coordinates
    faces = face_cascade.detectMultiScale(gray)
    # get face bounding box for overlay
    for (x,y,w,h) in faces:
      bbox_array = cv2.rectangle(bbox_array,(x,y),(x+w,y+h),(255,0,0),2)

    bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
    # convert overlay of bbox into bytes
    bbox_bytes = bbox_to_bytes(bbox_array)
    # update bbox so next frame gets new overlay
    bbox = bbox_bytes
